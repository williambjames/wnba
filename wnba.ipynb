# %%
pip install scikit-learn
# Out:
# Defaulting to user installation because normal site-packages is not writeableNote: you may need to restart the kernel to use updated packages.
#
# Collecting scikit-learn
#   Downloading scikit_learn-1.6.0-cp312-cp312-win_amd64.whl.metadata (15 kB)
# Requirement already satisfied: numpy>=1.19.5 in c:\users\willi\appdata\roaming\python\python312\site-packages (from scikit-learn) (2.1.2)
# Collecting scipy>=1.6.0 (from scikit-learn)
#   Downloading scipy-1.14.1-cp312-cp312-win_amd64.whl.metadata (60 kB)
# Collecting joblib>=1.2.0 (from scikit-learn)
#   Downloading joblib-1.4.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn)
#   Downloading threadpoolctl-3.5.0-py3-none-any.whl.metadata (13 kB)
# Downloading scikit_learn-1.6.0-cp312-cp312-win_amd64.whl (11.1 MB)
#    ---------------------------------------- 0.0/11.1 MB ? eta -:--:--
#    ---- ----------------------------------- 1.3/11.1 MB 11.3 MB/s eta 0:00:01
#    ------------------------- -------------- 7.1/11.1 MB 22.9 MB/s eta 0:00:01
#    ---------------------------------------- 11.1/11.1 MB 24.8 MB/s eta 0:00:00
# Downloading joblib-1.4.2-py3-none-any.whl (301 kB)
# Downloading scipy-1.14.1-cp312-cp312-win_amd64.whl (44.5 MB)
#    ---------------------------------------- 0.0/44.5 MB ? eta -:--:--
#    ----- ---------------------------------- 6.3/44.5 MB 32.2 MB/s eta 0:00:02
#    ----------- ---------------------------- 13.1/44.5 MB 31.6 MB/s eta 0:00:01
#    ------------------ --------------------- 20.2/44.5 MB 33.5 MB/s eta 0:00:01
#    ------------------------ --------------- 27.5/44.5 MB 34.2 MB/s eta 0:00:01
#    ------------------------------- -------- 34.6/44.5 MB 33.8 MB/s eta 0:00:01
#    ------------------------------------- -- 41.7/44.5 MB 34.4 MB/s eta 0:00:01
#    ---------------------------------------- 44.5/44.5 MB 33.3 MB/s eta 0:00:00
# Downloading threadpoolctl-3.5.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, scipy, joblib, scikit-learn
# Successfully installed joblib-1.4.2 scikit-learn-1.6.0 scipy-1.14.1 threadpoolctl-3.5.0

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import Ridge
from sklearn.model_selection import KFold

# %%
boxes = pd.read_csv('box_21_24.csv')

poss = pd.read_csv('poss_21_24.csv')
# Out:
# C:\Users\willi\AppData\Local\Temp\ipykernel_49260\3946115115.py:1: DtypeWarning: Columns (27) have mixed types. Specify dtype option on import or set low_memory=False.
#   boxes = pd.read_csv('box_21_24.csv')

# %%
boxes_ids_years
# Out:
#          game_id  season
# 0      401370398    2021
# 22     401370397    2021
# 44     401370396    2021
# 66     401370395    2021
# 88     401370442    2021
# ...          ...     ...
# 21549  401620222    2024
# 21569  401620220    2024
# 21590  401620221    2024
# 21613  401620219    2024
# 21636  401620178    2024
#
# [978 rows x 2 columns]

# %%
boxes_ids_years
# Out:
#             minutes
# athlete_id
# 91.0         1955.0
# 585.0        3550.0
# 689.0         464.0
# 764.0        2116.0
# 766.0        1831.0
# ...             ...
# 5017726.0     831.0
# 5105752.0     139.0
# 5106150.0     176.0
# 5130672.0     728.0
# 5209660.0     818.0
#
# [268 rows x 1 columns]

# %%
# poss = poss.drop(columns=['Unnamed: 0'])
boxes_ids_years = boxes[['game_id', 'season']].drop_duplicates()
poss = poss.merge(boxes_ids_years, on=['game_id'])

# %%
boxes_minutes = boxes[['game_id', 'season', 'minutes', 'athlete_id','athlete_display_name']].groupby(['athlete_id','season'], as_index=False).agg({'minutes':'sum'})
boxes_minutes
# Out:
#      athlete_id  season  minutes
# 0          91.0    2021    908.0
# 1          91.0    2022   1047.0
# 2         585.0    2021    758.0
# 3         585.0    2022    961.0
# 4         585.0    2023    709.0
# ..          ...     ...      ...
# 643   5105752.0    2024    139.0
# 644   5106150.0    2024    176.0
# 645   5130672.0    2023    461.0
# 646   5130672.0    2024    267.0
# 647   5209660.0    2024    818.0
#
# [648 rows x 3 columns]

# %%
player_cols = [
    'off1', 'off2', 'off3', 'off4', 'off5',
    'def1', 'def2', 'def3', 'def4', 'def5'
]

# %%
def build_player_list(poss):
    players = list(
        set(list(poss['off1'].unique()) + list(poss['off2'].unique()) + 
            list(poss['off3']) + list(poss['off4'].unique()) + 
            list(poss['off5'].unique()) + list(poss['def1'].unique()) + 
            list(poss['def2'].unique()) + list(poss['def3'].unique()) + 
            list(poss['def4'].unique()) + list(poss['def5'].unique())))
    players.sort()
    return players



def map_players(row_in, players):
    p1 = row_in[0]
    p2 = row_in[1]
    p3 = row_in[2]
    p4 = row_in[3]
    p5 = row_in[4]
    p6 = row_in[5]
    p7 = row_in[6]
    p8 = row_in[7]
    p9 = row_in[8]
    p10 = row_in[9]

    rowOut = np.zeros([len(players) * 2])

    rowOut[players.index(p1)] = 1
    rowOut[players.index(p2)] = 1
    rowOut[players.index(p3)] = 1
    rowOut[players.index(p4)] = 1
    rowOut[players.index(p5)] = 1

    rowOut[players.index(p6) + len(players)] = -1
    rowOut[players.index(p7) + len(players)] = -1
    rowOut[players.index(p8) + len(players)] = -1
    rowOut[players.index(p9) + len(players)] = -1
    rowOut[players.index(p10) + len(players)] = -1

    return rowOut

def convert_to_matricies(possessions, name, players):
    # extract only the columns we need

    # Convert the columns of player ids into a numpy matrix
    stints_x_base = possessions[player_cols].to_numpy()
    # Apply our mapping function to the numpy matrix
    stint_X_rows = np.apply_along_axis(map_players, 1, stints_x_base, players)

    # Convert the column of target values into a numpy matrix
    stint_Y_rows = possessions[name].to_numpy()

    # return matricies and possessions series
    return stint_X_rows, stint_Y_rows

# Convert lambda value to alpha needed for ridge CV
def lambda_to_alpha(lambda_value, samples):
    return (lambda_value * samples) / 2.0

# Convert RidgeCV alpha back into a lambda value
def alpha_to_lambda(alpha_value, samples):
    return (alpha_value * 2.0) / samples

def calculate_rapm(train_x, train_y, lambdas, name, players):
    # convert our lambdas to alphas
    alphas = [lambda_to_alpha(l, train_x.shape[0]) for l in lambdas]

    # create a 5 fold CV ridgeCV model. Our target data is not centered at 0, so we want to fit to an intercept.
    clf = RidgeCV(alphas=alphas, cv=5, fit_intercept=True)

    # fit our training data
    model = clf.fit(train_x, train_y,)

    # convert our list of players into a mx1 matrix
    player_arr = np.transpose(np.array(players).reshape(1, len(players)))

    # extract our coefficients into the offensive and defensive parts
    coef_offensive_array = model.coef_[0:len(players)][np.newaxis].T
    coef_defensive_array = model.coef_[len(players):][np.newaxis].T

    # concatenate the offensive and defensive values with the playey ids into a mx3 matrix
    player_id_with_coef = np.concatenate([player_arr, coef_offensive_array, coef_defensive_array], axis=1)
    # build a dataframe from our matrix
    players_coef = pd.DataFrame(player_id_with_coef)
    intercept = model.intercept_

    # apply new column names
    players_coef.columns = ['playerId', 'O{0}'.format(name),         
    'D{0}'.format(name)]

    # Add the offesnive and defensive components together (we should really be weighing this to the number of offensive and defensive possession played as they are often not equal).
    players_coef[name] = players_coef['O{0}'.format(name)] + players_coef['D{0}'.format(name)]

    # rank the values
    players_coef['{0} Rank'.format(name)] = players_coef[name].rank(ascending=False)
    players_coef['O{0} Rank'.format(name)] = players_coef[         
        'O{0}'.format(name)].rank(ascending=False)
    players_coef['D{0} Rank'.format(name)] = players_coef[
        'D{0}'.format(name)].rank(ascending=False)

    return players_coef, intercept


def calculate_rapm_with_decay(possessions, name, lambdas_rapm, players, current_year=2023, decay_factor=0.9):
    """
    possessions: DataFrame with columns including 'season', player_cols (off1..def5), and target column `name`.
    name: the target variable (e.g., 'PPP', 'points_scored')
    lambdas_rapm: list of lambdas to try (e.g., [0.01, 0.05, 0.1])
    players: list of all players
    current_year: int, the reference year from which decay is computed
    decay_factor: float, exponential decay per season (e.g., 0.9 means 10% downweight per year older)
    """

    # Compute weights based on how old the season is
    # This assumes possessions has a 'season' column
    possessions['years_ago'] = current_year - possessions['season']
    possessions['weight'] = decay_factor ** possessions['years_ago']

    # Convert possessions to X and y
    train_x, train_y = convert_to_matricies(possessions, name, players)
    sample_weights = possessions['weight'].values

    # Convert lambdas to alphas
    alphas = [lambda_to_alpha(l, train_x.shape[0]) for l in lambdas_rapm]

    # We'll do manual cross-validation to pick the best alpha
    # For RAPM, a common scoring metric might be MSE or R^2.
    # Here we'll use R^2 for simplicity, but you could use neg_mean_squared_error too.
    best_alpha = None
    best_score = -np.inf
    kf = KFold(n_splits=5, shuffle=True, random_state=42)

    for alpha in alphas:
        cv_scores = []
        for train_index, val_index in kf.split(train_x):
            X_train_fold, X_val_fold = train_x[train_index], train_x[val_index]
            y_train_fold, y_val_fold = train_y[train_index], train_y[val_index]
            w_train_fold = sample_weights[train_index]

            model = Ridge(alpha=alpha, fit_intercept=True)
            model.fit(X_train_fold, y_train_fold, sample_weight=w_train_fold)
            score = model.score(X_val_fold, y_val_fold)
            cv_scores.append(score)

        avg_score = np.mean(cv_scores)
        if avg_score > best_score:
            best_score = avg_score
            best_alpha = alpha

    # Now fit the final model with the best alpha
    final_model = Ridge(alpha=best_alpha, fit_intercept=True)
    final_model.fit(train_x, train_y, sample_weight=sample_weights)

    # Extract coefficients similarly to the original code
    player_arr = np.transpose(np.array(players).reshape(1, len(players)))

    coef_offensive_array = final_model.coef_[0:len(players)][np.newaxis].T
    coef_defensive_array = final_model.coef_[len(players):][np.newaxis].T

    player_id_with_coef = np.concatenate([player_arr, coef_offensive_array, coef_defensive_array], axis=1)
    players_coef = pd.DataFrame(player_id_with_coef, columns=['playerId', 'ORAPM', 'DRAPM'])
    players_coef[name] = players_coef['ORAPM'] + players_coef['DRAPM']

    players_coef['RAPM Rank'] = players_coef[name].rank(ascending=False)
    players_coef['ORAPM Rank'] = players_coef['ORAPM'].rank(ascending=False)
    players_coef['DRAPM Rank'] = players_coef['DRAPM'].rank(ascending=False)

    intercept = final_model.intercept_

    return players_coef, intercept, best_alpha

# %%
poss.dtypes
# Out:
# game_id          int64
# possession_id    int64
# off1             int64
# off2             int64
# off3             int64
# off4             int64
# off5             int64
# def1             int64
# def2             int64
# def3             int64
# def4             int64
# def5             int64
# points_scored    int64
# PPP              int64
# dtype: object

# %%
player_list = build_player_list(poss)

# %%
poss['PPP'] = poss['points_scored'] * 100

# %%
train_x, train_y = convert_to_matricies(poss, 'PPP', player_list)

# %%
lambdas_rapm = [.01, .05, .1]

# %%
results, intercept, best_alpha = calculate_rapm_with_decay(poss, 'PPP', lambdas_rapm,  player_list)

# %%
pd.set_option('display.max_columns', 500)

# %%
# Out:
#    Unnamed: 0    game_id  season  season_type   game_date  \
# 0           1  401370398    2021            3  2021-10-17
# 1           2  401370398    2021            3  2021-10-17
# 2           3  401370398    2021            3  2021-10-17
# 3           4  401370398    2021            3  2021-10-17
# 4           5  401370398    2021            3  2021-10-17
#
#         game_date_time  athlete_id  athlete_display_name  team_id team_name  \
# 0  2021-10-17 15:11:00   3142086.0        Brianna Turner       11   Mercury
# 1  2021-10-17 15:11:00   2490553.0       Brittney Griner       11   Mercury
# 2  2021-10-17 15:11:00       585.0         Diana Taurasi       11   Mercury
# 3  2021-10-17 15:11:00      1107.0            Shey Peddy       11   Mercury
# 4  2021-10-17 15:11:00   2491205.0  Skylar Diggins-Smith       11   Mercury
#
#   team_location team_short_display_name  minutes  field_goals_made  \
# 0       Phoenix                 Mercury     36.0               2.0
# 1       Phoenix                 Mercury     38.0              12.0
# 2       Phoenix                 Mercury     33.0               4.0
# 3       Phoenix                 Mercury     18.0               0.0
# 4       Phoenix                 Mercury     37.0               7.0
#
#    field_goals_attempted  three_point_field_goals_made  \
# 0                    6.0                           0.0
# 1                   19.0                           0.0
# 2                   16.0                           3.0
# 3                    3.0                           0.0
# 4                   18.0                           2.0
#
#    three_point_field_goals_attempted  free_throws_made  free_throws_attempted  \
# 0                                0.0               1.0                    1.0
# 1                                1.0               4.0                    4.0
# 2                                9.0               5.0                    6.0
# 3                                1.0               0.0                    0.0
# 4                                7.0               0.0                    0.0
#
#    offensive_rebounds  defensive_rebounds  rebounds  assists  steals  blocks  \
# 0                 5.0                 7.0      12.0      2.0     2.0     2.0
# 1                 0.0                 7.0       7.0      2.0     1.0     1.0
# 2                 0.0                 2.0       2.0      2.0     0.0     1.0
# 3                 0.0                 4.0       4.0      3.0     1.0     0.0
# 4                 0.0                 2.0       2.0      8.0     0.0     1.0
#
#    turnovers  fouls plus_minus  points  starter  ejected  did_not_play  \
# 0        3.0    4.0         -9     5.0     True    False         False
# 1        0.0    0.0         -4    28.0     True    False         False
# 2        3.0    4.0        -22    16.0     True    False         False
# 3        1.0    1.0        -11     0.0     True    False         False
# 4        5.0    1.0         -2    16.0     True    False         False
#
#              reason  active  athlete_jersey athlete_short_name  \
# 0  COACH'S DECISION    True            21.0          B. Turner
# 1  COACH'S DECISION    True            42.0          B. Griner
# 2  COACH'S DECISION    True             3.0         D. Taurasi
# 3  COACH'S DECISION    True            11.0           S. Peddy
# 4  COACH'S DECISION    True             4.0   S. Diggins-Smith
#
#                                athlete_headshot_href athlete_position_name  \
# 0  https://a.espncdn.com/i/headshots/wnba/players...               Forward
# 1  https://a.espncdn.com/i/headshots/wnba/players...                Center
# 2  https://a.espncdn.com/i/headshots/wnba/players...                 Guard
# 3  https://a.espncdn.com/i/headshots/wnba/players...                 Guard
# 4  https://a.espncdn.com/i/headshots/wnba/players...                 Guard
#
#   athlete_position_abbreviation team_display_name        team_uid  \
# 0                             F   Phoenix Mercury  s:40~l:59~t:11
# 1                             C   Phoenix Mercury  s:40~l:59~t:11
# 2                             G   Phoenix Mercury  s:40~l:59~t:11
# 3                             G   Phoenix Mercury  s:40~l:59~t:11
# 4                             G   Phoenix Mercury  s:40~l:59~t:11
#
#          team_slug                                          team_logo  \
# 0  phoenix-mercury  https://a.espncdn.com/i/teamlogos/wnba/500/phx...
# 1  phoenix-mercury  https://a.espncdn.com/i/teamlogos/wnba/500/phx...
# 2  phoenix-mercury  https://a.espncdn.com/i/teamlogos/wnba/500/phx...
# 3  phoenix-mercury  https://a.espncdn.com/i/teamlogos/wnba/500/phx...
# 4  phoenix-mercury  https://a.espncdn.com/i/teamlogos/wnba/500/phx...
#
#   team_abbreviation team_color team_alternate_color home_away  team_winner  \
# 0               PHX     3a267d               e56020      away        False
# 1               PHX     3a267d               e56020      away        False
# 2               PHX     3a267d               e56020      away        False
# 3               PHX     3a267d               e56020      away        False
# 4               PHX     3a267d               e56020      away        False
#
#    team_score  opponent_team_id opponent_team_name opponent_team_location  \
# 0          74                19                Sky                Chicago
# 1          74                19                Sky                Chicago
# 2          74                19                Sky                Chicago
# 3          74                19                Sky                Chicago
# 4          74                19                Sky                Chicago
#
#   opponent_team_display_name opponent_team_abbreviation  \
# 0                Chicago Sky                        CHI
# 1                Chicago Sky                        CHI
# 2                Chicago Sky                        CHI
# 3                Chicago Sky                        CHI
# 4                Chicago Sky                        CHI
#
#                                   opponent_team_logo opponent_team_color  \
# 0  https://a.espncdn.com/i/teamlogos/wnba/500/chi...              4f91cd
# 1  https://a.espncdn.com/i/teamlogos/wnba/500/chi...              4f91cd
# 2  https://a.espncdn.com/i/teamlogos/wnba/500/chi...              4f91cd
# 3  https://a.espncdn.com/i/teamlogos/wnba/500/chi...              4f91cd
# 4  https://a.espncdn.com/i/teamlogos/wnba/500/chi...              4f91cd
#
#   opponent_team_alternate_color  opponent_team_score
# 0                        f1f2f3                   80
# 1                        f1f2f3                   80
# 2                        f1f2f3                   80
# 3                        f1f2f3                   80
# 4                        f1f2f3                   80

# %%
results = np.round(results, decimals=2)
results = results.reindex(sorted(results.columns), axis=1)
boxes = boxes.drop_duplicates(subset=['athlete_id'])
results = results.merge(boxes[['athlete_id','athlete_display_name','team_name']], left_on='playerId', right_on='athlete_id', how='left')
results = results.rename(columns={'athlete_display_name': 'Player Name', 'PPP':'RAPM'})

# %%
results
# Out:
#      DRAPM  DRAPM Rank  ORAPM  ORAPM Rank  RAPM  RAPM Rank   playerId  \
# 0    -0.43       206.0   1.90        12.0  1.47       21.0       91.0
# 1    -1.30       252.0   1.19        28.0 -0.11      133.0      585.0
# 2    -0.33       193.0  -0.76       220.0 -1.09      235.0      689.0
# 3    -0.40       203.0   1.65        18.0  1.25       27.0      764.0
# 4    -0.54       216.0   0.27        65.0 -0.27      159.0      766.0
# ..     ...         ...    ...         ...   ...        ...        ...
# 255   0.93        21.0  -0.61       210.0  0.32       69.0  5017726.0
# 256   0.28        80.0  -0.13       129.0  0.15       84.0  5105752.0
# 257  -0.21       175.0  -0.31       168.0 -0.51      185.0  5106150.0
# 258  -0.89       239.0  -0.62       213.0 -1.51      251.0  5130672.0
# 259  -1.08       247.0   0.38        55.0 -0.70      206.0  5209660.0
#
#      athlete_id       Player Name
# 0          91.0          Sue Bird
# 1         585.0     Diana Taurasi
# 2         689.0    Candice Dupree
# 3         764.0     Allie Quigley
# 4         766.0     Sylvia Fowles
# ..          ...               ...
# 255   5017726.0    Jade Melbourne
# 256   5105752.0       Alissa Pili
# 257   5106150.0  Stephanie Soares
# 258   5130672.0      Ivana Dojkic
# 259   5209660.0        Sevgi Uzun
#
# [260 rows x 9 columns]

# %%
results.sort_values(by='RAPM', ascending=False).head(50)
# Out:
#      DRAPM  DRAPM Rank  ORAPM  ORAPM Rank  RAPM  RAPM Rank   playerId  \
# 73    0.27        84.0   4.15         1.0  4.42        1.0  2998928.0
# 36    1.64         3.0   2.02        11.0  3.66        2.0  2491205.0
# 96    0.26        86.0   3.20         2.0  3.46        3.0  3065570.0
# 6     1.09        16.0   2.29         5.0  3.38        4.0      812.0
# 76    1.29         8.0   1.69        17.0  2.98        5.0  2999101.0
# 38    1.29         7.0   1.55        20.0  2.85        6.0  2491877.0
# 40    0.53        43.0   2.03        10.0  2.55        7.0  2529122.0
# 248   1.75         1.0   0.78        39.0  2.53        8.0  4683006.0
# 91    1.26        10.0   1.19        27.0  2.46        9.0  3058895.0
# 11    0.51        45.0   1.88        14.0  2.40       10.0      869.0
# 43    1.03        18.0   1.25        25.0  2.28       11.0  2529140.0
# 150  -0.38       201.0   2.55         3.0  2.17       12.0  4065870.0
# 129   0.62        36.0   1.52        21.0  2.15       13.0  3917450.0
# 183  -0.01       137.0   2.11         8.0  2.10       14.0  4281929.0
# 17    0.49        48.0   1.59        19.0  2.09       15.0      981.0
# 47   -0.14       167.0   2.13         7.0  1.99       16.0  2529205.0
# 112   0.18        95.0   1.48        22.0  1.67       17.0  3149391.0
# 153  -0.89       238.0   2.52         4.0  1.63       18.0  4066533.0
# 80    0.44        53.0   1.16        29.0  1.60       19.0  3027368.0
# 125   0.25        89.0   1.23        26.0  1.48       20.0  3913881.0
# 0    -0.43       206.0   1.90        12.0  1.47       21.0       91.0
# 234   0.94        20.0   0.52        48.0  1.46       22.0  4433402.0
# 226  -0.67       224.0   2.11         9.0  1.44       23.0  4432831.0
# 111  -0.01       135.0   1.37        24.0  1.36       24.0  3146151.0
# 92    0.55        42.0   0.80        38.0  1.35       25.0  3058901.0
# 16    1.57         4.0  -0.26       158.0  1.31       26.0      924.0
# 3    -0.40       203.0   1.65        18.0  1.25       27.0      764.0
# 66    0.29        78.0   0.93        33.0  1.21       28.0  2955898.0
# 98    0.83        25.0   0.36        58.0  1.19       29.0  3099736.0
# 69   -0.28       188.0   1.42        23.0  1.15       30.0  2987869.0
# 214   1.27         9.0  -0.14       130.0  1.13       31.0  4398935.0
# 119   0.57        40.0   0.55        45.0  1.12       33.0  3906753.0
# 209   1.49         5.0  -0.37       180.0  1.12       32.0  4398911.0
# 121   1.25        12.0  -0.17       141.0  1.08       34.0  3906972.0
# 117  -0.83       234.0   1.88        13.0  1.05       35.0  3904576.0
# 113   1.20        13.0  -0.18       143.0  1.02       36.0  3156318.0
# 35    0.07       117.0   0.87        36.0  0.94       37.0  2490794.0
# 26   -0.24       181.0   1.13        31.0  0.89       38.0     1068.0
# 42    0.19        93.0   0.67        41.0  0.86       39.0  2529137.0
# 32    0.26        88.0   0.53        47.0  0.79       41.0  2327695.0
# 10    1.16        14.0  -0.37       179.0  0.79       40.0      860.0
# 158   0.49        49.0   0.27        66.0  0.76       43.0  4066585.0
# 34   -1.37       255.0   2.13         6.0  0.76       42.0  2490553.0
# 126  -1.10       248.0   1.82        15.0  0.72       44.0  3913903.0
# 60    0.31        76.0   0.41        54.0  0.71       45.0  2569044.0
# 193   0.74        28.0  -0.05       111.0  0.69       46.0  4398674.0
# 25   -0.23       179.0   0.89        34.0  0.66       47.0     1054.0
# 142   0.43        56.0   0.17        78.0  0.59       48.0  4065780.0
# 56    0.41        57.0   0.17        75.0  0.58       49.0  2566186.0
# 23    0.66        31.0  -0.09       122.0  0.57       50.0     1017.0
#
#      athlete_id           Player Name team_name
# 73    2998928.0       Breanna Stewart     Storm
# 36    2491205.0  Skylar Diggins-Smith   Mercury
# 96    3065570.0           Kelsey Plum      Aces
# 6         812.0        Candace Parker       Sky
# 76    2999101.0         Jonquel Jones       Sun
# 38    2491877.0     Elena Delle Donne   Mystics
# 40    2529122.0          Chelsea Gray      Aces
# 248   4683006.0        Leonie Fiebich   Liberty
# 91    3058895.0         Brionna Jones       Sun
# 11        869.0        DeWanna Bonner       Sun
# 43    2529140.0         Alyssa Thomas       Sun
# 150   4065870.0          Jackie Young      Aces
# 129   3917450.0      Napheesa Collier      Lynx
# 183   4281929.0         Satou Sabally     Wings
# 17        981.0  Courtney Vandersloot       Sky
# 47    2529205.0         Kayla McBride      Lynx
# 112   3149391.0           A'ja Wilson      Aces
# 153   4066533.0       Sabrina Ionescu   Liberty
# 80    3027368.0        Emma Meesseman       Sky
# 125   3913881.0          Alanna Smith   Mercury
# 0          91.0              Sue Bird     Storm
# 234   4433402.0           Angel Reese       Sky
# 226   4432831.0         Aliyah Boston     Fever
# 111   3146151.0          Ariel Atkins   Mystics
# 92    3058901.0          Allisha Gray     Wings
# 16        924.0          Alysha Clark   Mystics
# 3         764.0         Allie Quigley       Sky
# 66    2955898.0        Damiris Dantas      Lynx
# 98    3099736.0      Stephanie Talbot     Storm
# 69    2987869.0           Jewell Loyd     Storm
# 214   4398935.0       Veronica Burton     Wings
# 119   3906753.0      Natisha Hiedeman       Sun
# 209   4398911.0        Shakira Austin   Mystics
# 121   3906972.0      Bridget Carleton      Lynx
# 117   3904576.0         Marina Mabrey     Wings
# 113   3156318.0        Kristy Wallace     Dream
# 35    2490794.0     Layshia Clarendon      Lynx
# 26       1068.0        Nneka Ogwumike    Sparks
# 42    2529137.0         Natasha Cloud   Mystics
# 32    2327695.0       Rebekah Gardner       Sky
# 10        860.0        Briann January       Sun
# 158   4066585.0   Crystal Dangerfield      Lynx
# 34    2490553.0       Brittney Griner   Mercury
# 126   3913903.0        Teaira McCowan     Fever
# 60    2569044.0         Temi Fagbenle     Fever
# 193   4398674.0          Rhyne Howard     Dream
# 25       1054.0         Tiffany Hayes     Dream
# 142   4065780.0         Kaila Charles       Sun
# 56    2566186.0         Rachel Banham      Lynx
# 23       1017.0           Liz Cambage      Aces

# %%
results.groupby('team_name').agg({'RAPM':'sum'}).sort_values(by='RAPM', ascending=False)
# Out:
#             RAPM
# team_name
# Sun        11.66
# Aces        6.55
# Sky         4.63
# Lynx        4.49
# Mystics     2.36
# Storm       2.29
# Mercury    -0.83
# Liberty    -4.14
# Wings      -4.15
# Dream      -5.52
# Fever      -8.24
# Sparks     -8.72
